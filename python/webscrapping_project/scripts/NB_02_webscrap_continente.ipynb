# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
from bs4 import BeautifulSoup as bs
import requests

import time
import json
from requests.models import Response

import random
import datetime

import pandas as pd

from google.colab import drive

# %%
def extract_products(soup_response, main_category):

  # The list of products in the page
  products = [json.loads(item["data-product-tile-impression"]) for item in soup_response.find_all('div') if "data-product-tile-impression" in item.attrs]
  # The list of quantity of each product
  products_quantity = [item.contents[0].replace('Quant. Mínima =', '').replace('Quant. Mínima=', '').replace('emb.', '').strip() if item.contents else 'none quantity' for item in soup_response.find_all("p",  class_=['pwc-tile--quantity col-tile--quantity', 'quantity-product-set quantity-product-set-grid'])]
  # The list of name of each product
  products_name = [json.loads(item.attrs['data-confirmation-image'])['title'] for item in soup_response.find_all("div", attrs= {'data-confirmation-image':True, 'class':'ct-image-container'})]
  # products_prices_p_unit = [value.contents[0].replace('\n', '') for index, value in enumerate(soup_response.find_all("span",  class_=['ct-price-value','pwc-m-unit'])) if (index) % 3 != 0]

  # The list of secondary prices of each product
  price_secondary = soup_response.find_all("div", class_="pwc-tile--price-secondary col-tile--price-secondary")

  # The list of prices_per_unit of each product 
  products_prices_p_unit = []
  [products_prices_p_unit.extend(item.find_all("span", class_="ct-price-value")) for item in price_secondary]

  # The list of unities of each product 
  products_unities = []
  [products_unities.extend(item.find_all("span", class_="pwc-m-unit")) for item in price_secondary]

  decrement_count = 0

  # Log of extraction 
  print('Names =', len(products_name), '// Quantity =', len(products_quantity),
        '// Price-p-Unit =', len(products_prices_p_unit), '// Units =', len(products_unities),
        '// Products =',  len(products))
  
  # Concatenate all product-related information into the same object
  # Most important part of extraction
  for index, product in enumerate(products):

    product['name'] = products_name[index]
    
    split_quantity_product = products_quantity[index].upper().split(" ")
    product['amount'] = "{} {}".format(split_quantity_product[0], split_quantity_product[1] if len(split_quantity_product) > 1 else '' )
    
    product['main_category'] = main_category
    
    product['full_category'] = product.pop('category')
    
    product['time_scraped'] = datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")

    # Recalculation index based on products with no secondary price
    relative_index = index - decrement_count

    find_product = soup_response.find("div", {'data-pid': product['id']})
    has_price_p_unit = find_product.find("div", class_="pwc-tile--price-secondary col-tile--price-secondary")

    #Check if the product have the secondary price-related
    if(len(products_prices_p_unit) != len(products) and not (has_price_p_unit)): 
      decrement_count += 1

      # Get the information of primary price-related
      price = find_product.find("div", class_="prices-wrapper")
      product_price = price.find('span', class_="ct-price-formatted").contents[0].replace('\n', '')
      product_unit = price.find('span', class_="pwc-m-unit").contents[0].replace('\n', '')

      product['currency'] = product_price[0]
      product['price_p_unit'] = product_price.replace(',', '.')[1:]
      product['unit'] = product_unit.replace('/', '').upper() 

    else:
      product['currency'] = products_prices_p_unit[relative_index].contents[0].replace('\n', '')[0]
      product['price_p_unit'] = products_prices_p_unit[relative_index].contents[0].replace('\n', '').replace(',', '.')[1:]
      product['unit'] = products_unities[relative_index].contents[0].replace('\n', '').replace('/', '').upper() 

    # Concat the information to pattern decided by group
    price_p_unit_concat = "{} {}/{}".format(product['price_p_unit'], product['currency'], product['unit'])
    product['quantity'] =  "{} | {}".format(products_quantity[index].upper(), price_p_unit_concat)

  return products

# %%
def extract_data(category_path): 

  all_scraped_values = []
  qtd_page_products = 24
  qtd_total_products = 0
  url = 'https://www.continente.pt/'
  url += category_path
  params = {'pmin': '0.01', 'start': '0', 'sz': qtd_page_products}

  condition = True

  while(condition):

    params['start'] = len(all_scraped_values)
    response = requests.get(url, params=params)
    soup = bs(response.content)

    # Log of URL and params request
    print(url, params)
    
    # Check if this soup response is a products page or not. 
    if(soup.find("div","search-results-products-counter d-flex justify-content-center")):
      products_page = soup.find("div","search-results-products-counter d-flex justify-content-center").contents[0]
      products_splited = products_page.split(" ")
      qtd_page_products = int(products_splited[0])
      qtd_total_products = int(products_splited[2])

      all_scraped_values += extract_products(soup, category_path)

      time.sleep(random.randint(10, 30))

      # Log extration
      print( 'Extracted =', len(all_scraped_values),  '// All Products=', qtd_total_products, '// Extract % =', (len(all_scraped_values) / qtd_total_products) * 100)

      condition = len(all_scraped_values) <= qtd_total_products

    else:
      condition = False

  return all_scraped_values

# %%
def extract_continent():
  url = 'https://www.continente.pt/'
  response = requests.get(url)
  soup = bs(response.content)

  list_all_request = []


  # Scrape all URLs to access the categories of the Continente website.  
  # url_list = [str(item['href']).replace(url, '') for item in soup.find_all('a', attrs={'class':'dropdown-link', 'role':'menuitem'})]
  # url_list = list(dict.fromkeys([url[:url.find('/')+1] for url in url_list]))
  # url_list = url_list[url_list.index('mercearia/'):url_list.index('mercearia/')+10] 

  # The list of categories defined by the group for analysis.
  url_list = ['mercearia', 'padaria-e-pastelaria', 'frutas-e-legumes', 'bio-e-escolhas-alimentares', 'laticinios-e-ovos', 'charcutaria-e-queijos',
  'peixaria-e-talho', 'congelados', 'refeicoes-faceis']

  # Iterate by the url_list and pass each category to extract_data(), and concatenate the returned values
  for url in url_list:
    print(url)    
    products = extract_data(url)
    df = pd.DataFrame(products)
    df.to_csv(url+'.csv')
    list_all_request += products
    time.sleep(random.randint(10, 30))

  # Return all values scrapped
  return list_all_request

# %%
if __name__ == '__main__':
    drive.mount('drive')

    all_products = extract_continent()
    
    df = pd.DataFrame(all_products)
    
    # The list of columns defined by the group for final dataset
    columns = ['time_scraped', 'quantity', 'main_category', 'name', 'amount', 'unit', 'price', 'price_p_unit', 'currency', 'id', 'brand', 'full_category', 'variant', 'channel']

    df = df[columns]

    df.to_csv('data.csv')
    
    df
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
# mercearia
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 0, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 24 // All Products= 5064 // Extract % = 0.47393364928909953
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 24, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 22 // Units = 22 // Products = 24
# Extracted = 48 // All Products= 5064 // Extract % = 0.9478672985781991
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 48, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 72 // All Products= 5064 // Extract % = 1.4218009478672986
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 72, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 96 // All Products= 5064 // Extract % = 1.8957345971563981
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 96, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 120 // All Products= 5064 // Extract % = 2.3696682464454977
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 120, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 144 // All Products= 5064 // Extract % = 2.843601895734597
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 144, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 168 // All Products= 5064 // Extract % = 3.3175355450236967
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 168, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 192 // All Products= 5064 // Extract % = 3.7914691943127963
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 192, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 216 // All Products= 5064 // Extract % = 4.265402843601896
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 216, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 240 // All Products= 5064 // Extract % = 4.739336492890995
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 240, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 264 // All Products= 5064 // Extract % = 5.213270142180095
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 264, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 288 // All Products= 5064 // Extract % = 5.687203791469194
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 288, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 312 // All Products= 5064 // Extract % = 6.161137440758294
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 312, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 336 // All Products= 5064 // Extract % = 6.6350710900473935
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 336, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 360 // All Products= 5064 // Extract % = 7.109004739336493
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 360, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 384 // All Products= 5064 // Extract % = 7.5829383886255926
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 384, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 408 // All Products= 5064 // Extract % = 8.056872037914692
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 408, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 432 // All Products= 5064 // Extract % = 8.530805687203792
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 432, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 456 // All Products= 5064 // Extract % = 9.004739336492891
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 456, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 480 // All Products= 5064 // Extract % = 9.47867298578199
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 480, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 504 // All Products= 5064 // Extract % = 9.95260663507109
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 504, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 528 // All Products= 5064 // Extract % = 10.42654028436019
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 528, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 552 // All Products= 5064 // Extract % = 10.90047393364929
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 552, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 576 // All Products= 5064 // Extract % = 11.374407582938389
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 576, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 600 // All Products= 5064 // Extract % = 11.848341232227488
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 600, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 624 // All Products= 5064 // Extract % = 12.322274881516588
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 624, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 648 // All Products= 5064 // Extract % = 12.796208530805686
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 648, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 672 // All Products= 5064 // Extract % = 13.270142180094787
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 672, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 696 // All Products= 5064 // Extract % = 13.744075829383887
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 696, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 720 // All Products= 5064 // Extract % = 14.218009478672986
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 720, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 744 // All Products= 5064 // Extract % = 14.691943127962084
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 744, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 768 // All Products= 5064 // Extract % = 15.165876777251185
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 768, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 792 // All Products= 5064 // Extract % = 15.639810426540285
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 792, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 816 // All Products= 5064 // Extract % = 16.113744075829384
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 816, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 840 // All Products= 5064 // Extract % = 16.587677725118482
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 840, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 864 // All Products= 5064 // Extract % = 17.061611374407583
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 864, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 888 // All Products= 5064 // Extract % = 17.535545023696685
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 888, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 912 // All Products= 5064 // Extract % = 18.009478672985782
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 912, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 936 // All Products= 5064 // Extract % = 18.48341232227488
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 936, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 960 // All Products= 5064 // Extract % = 18.95734597156398
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 960, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 984 // All Products= 5064 // Extract % = 19.431279620853083
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 984, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1008 // All Products= 5064 // Extract % = 19.90521327014218
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1008, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1032 // All Products= 5064 // Extract % = 20.379146919431278
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1032, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1056 // All Products= 5064 // Extract % = 20.85308056872038
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1056, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1080 // All Products= 5064 // Extract % = 21.32701421800948
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1080, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1104 // All Products= 5064 // Extract % = 21.80094786729858
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1104, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1128 // All Products= 5064 // Extract % = 22.274881516587676
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1128, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1152 // All Products= 5064 // Extract % = 22.748815165876778
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1152, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1176 // All Products= 5064 // Extract % = 23.22274881516588
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1176, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1200 // All Products= 5064 // Extract % = 23.696682464454977
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1200, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1224 // All Products= 5064 // Extract % = 24.170616113744074
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1224, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 1248 // All Products= 5064 // Extract % = 24.644549763033176
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 1248, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2376, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2400 // All Products= 5063 // Extract % = 47.402725656725266
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2400, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2424 // All Products= 5063 // Extract % = 47.87675291329251
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2424, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2448 // All Products= 5063 // Extract % = 48.35078016985977
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2448, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2472 // All Products= 5063 // Extract % = 48.82480742642702
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2472, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2496 // All Products= 5063 // Extract % = 49.298834682994276
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2496, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2520 // All Products= 5063 // Extract % = 49.77286193956152
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2520, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2544 // All Products= 5063 // Extract % = 50.24688919612878
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2544, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2568 // All Products= 5063 // Extract % = 50.72091645269603
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2568, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2592 // All Products= 5063 // Extract % = 51.194943709263285
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2592, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2616 // All Products= 5063 // Extract % = 51.66897096583054
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2616, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2640 // All Products= 5063 // Extract % = 52.142998222397786
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2640, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2664 // All Products= 5063 // Extract % = 52.61702547896504
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2664, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2688 // All Products= 5063 // Extract % = 53.091052735532294
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2688, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2712 // All Products= 5063 // Extract % = 53.56507999209954
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2712, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2736 // All Products= 5063 // Extract % = 54.039107248666795
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2736, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2760 // All Products= 5063 // Extract % = 54.51313450523405
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2760, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2784 // All Products= 5063 // Extract % = 54.9871617618013
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2784, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2808 // All Products= 5063 // Extract % = 55.46118901836855
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2808, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2832 // All Products= 5063 // Extract % = 55.935216274935804
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2832, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2856 // All Products= 5063 // Extract % = 56.40924353150306
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2856, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2880 // All Products= 5064 // Extract % = 56.872037914691944
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2880, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2904 // All Products= 5064 // Extract % = 57.345971563981045
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2904, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2928 // All Products= 5064 // Extract % = 57.81990521327014
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2928, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2952 // All Products= 5064 // Extract % = 58.29383886255924
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2952, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 2976 // All Products= 5064 // Extract % = 58.767772511848335
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 2976, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3000 // All Products= 5064 // Extract % = 59.241706161137444
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3000, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3024 // All Products= 5064 // Extract % = 59.71563981042654
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3024, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3048 // All Products= 5064 // Extract % = 60.18957345971564
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3048, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3072 // All Products= 5064 // Extract % = 60.66350710900474
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3072, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3096 // All Products= 5064 // Extract % = 61.137440758293835
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3096, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 3120 // All Products= 5064 // Extract % = 61.61137440758294
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3120, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3144 // All Products= 5064 // Extract % = 62.08530805687204
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3144, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3168 // All Products= 5064 // Extract % = 62.55924170616114
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3168, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3192 // All Products= 5063 // Extract % = 63.045625123444594
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3192, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3216 // All Products= 5063 // Extract % = 63.51965238001185
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3216, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3240 // All Products= 5063 // Extract % = 63.9936796365791
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3240, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3264 // All Products= 5063 // Extract % = 64.46770689314636
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3264, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3288 // All Products= 5063 // Extract % = 64.9417341497136
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3288, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3312 // All Products= 5063 // Extract % = 65.41576140628086
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3312, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3336 // All Products= 5063 // Extract % = 65.88978866284812
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3336, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3360 // All Products= 5063 // Extract % = 66.36381591941537
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3360, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3384 // All Products= 5063 // Extract % = 66.83784317598261
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3384, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3408 // All Products= 5063 // Extract % = 67.31187043254987
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3408, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3432 // All Products= 5063 // Extract % = 67.78589768911712
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3432, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3456 // All Products= 5063 // Extract % = 68.25992494568438
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3456, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 3480 // All Products= 5063 // Extract % = 68.73395220225163
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 3480, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4608, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4632 // All Products= 5063 // Extract % = 91.48726051747975
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4632, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4656 // All Products= 5063 // Extract % = 91.96128777404701
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4656, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4680 // All Products= 5063 // Extract % = 92.43531503061426
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4680, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4704 // All Products= 5063 // Extract % = 92.90934228718152
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4704, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4728 // All Products= 5063 // Extract % = 93.38336954374876
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4728, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4752 // All Products= 5063 // Extract % = 93.85739680031602
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4752, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4776 // All Products= 5063 // Extract % = 94.33142405688328
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4776, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4800 // All Products= 5063 // Extract % = 94.80545131345053
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4800, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4824 // All Products= 5063 // Extract % = 95.27947857001777
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4824, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4848 // All Products= 5063 // Extract % = 95.75350582658503
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4848, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4872 // All Products= 5063 // Extract % = 96.22753308315228
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4872, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4896 // All Products= 5063 // Extract % = 96.70156033971953
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4896, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4920 // All Products= 5063 // Extract % = 97.17558759628679
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4920, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4944 // All Products= 5063 // Extract % = 97.64961485285404
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4944, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4968 // All Products= 5063 // Extract % = 98.1236421094213
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4968, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 4992 // All Products= 5063 // Extract % = 98.59766936598855
# https://www.continente.pt/mercearia {'pmin': '0.01', 'start': 4992, 'sz': 24}
# ...
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 168 // All Products= 675 // Extract % = 24.88888888888889
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 168, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 192 // All Products= 675 // Extract % = 28.444444444444443
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 192, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 216 // All Products= 675 // Extract % = 32.0
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 216, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 240 // All Products= 675 // Extract % = 35.55555555555556
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 240, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 264 // All Products= 675 // Extract % = 39.111111111111114
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 264, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 288 // All Products= 675 // Extract % = 42.66666666666667
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 288, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 312 // All Products= 675 // Extract % = 46.22222222222222
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 312, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 336 // All Products= 675 // Extract % = 49.77777777777778
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 336, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 360 // All Products= 675 // Extract % = 53.333333333333336
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 360, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 384 // All Products= 675 // Extract % = 56.888888888888886
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 384, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 408 // All Products= 675 // Extract % = 60.44444444444444
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 408, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 432 // All Products= 676 // Extract % = 63.905325443786985
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 432, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 456 // All Products= 676 // Extract % = 67.45562130177515
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 456, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 480 // All Products= 676 // Extract % = 71.00591715976331
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 480, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 504 // All Products= 676 // Extract % = 74.55621301775149
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 504, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 528 // All Products= 676 // Extract % = 78.10650887573965
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 528, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 552 // All Products= 676 // Extract % = 81.65680473372781
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 552, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 576 // All Products= 676 // Extract % = 85.20710059171599
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 576, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 600 // All Products= 676 // Extract % = 88.75739644970415
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 600, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 624 // All Products= 676 // Extract % = 92.3076923076923
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 624, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 648 // All Products= 676 // Extract % = 95.85798816568047
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 648, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 672 // All Products= 676 // Extract % = 99.40828402366864
# https://www.continente.pt/peixaria-e-talho {'pmin': '0.01', 'start': 672, 'sz': 24}
# congelados
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 0, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 37 // All Products= 858 // Extract % = 4.312354312354312
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 37, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 74 // All Products= 858 // Extract % = 8.624708624708624
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 74, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 111 // All Products= 858 // Extract % = 12.937062937062937
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 111, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 148 // All Products= 859 // Extract % = 17.229336437718278
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 148, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 185 // All Products= 858 // Extract % = 21.56177156177156
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 185, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 222 // All Products= 858 // Extract % = 25.874125874125873
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 222, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 259 // All Products= 859 // Extract % = 30.151338766006987
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 259, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 296 // All Products= 858 // Extract % = 34.4988344988345
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 296, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 333 // All Products= 859 // Extract % = 38.766006984866124
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 333, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 370 // All Products= 858 // Extract % = 43.12354312354312
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 370, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 407 // All Products= 859 // Extract % = 47.38067520372526
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 407, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 444 // All Products= 858 // Extract % = 51.74825174825175
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 444, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 481 // All Products= 859 // Extract % = 55.9953434225844
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 481, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 518 // All Products= 859 // Extract % = 60.30267753201397
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 518, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 555 // All Products= 859 // Extract % = 64.61001164144355
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 555, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 592 // All Products= 859 // Extract % = 68.91734575087311
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 592, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 629 // All Products= 859 // Extract % = 73.22467986030267
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 629, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 666 // All Products= 859 // Extract % = 77.53201396973225
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 666, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 703 // All Products= 859 // Extract % = 81.83934807916181
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 703, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 740 // All Products= 859 // Extract % = 86.14668218859138
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 740, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 777 // All Products= 859 // Extract % = 90.45401629802096
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 777, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 36 // Units = 36 // Products = 37
# Extracted = 814 // All Products= 859 // Extract % = 94.76135040745052
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 814, 'sz': 24}
# Names = 37 // Quantity = 37 // Price-p-Unit = 37 // Units = 37 // Products = 37
# Extracted = 851 // All Products= 859 // Extract % = 99.0686845168801
# https://www.continente.pt/congelados {'pmin': '0.01', 'start': 851, 'sz': 24}
# refeicoes-faceis
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 0, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 24 // All Products= 558 // Extract % = 4.301075268817205
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 24, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 48 // All Products= 558 // Extract % = 8.60215053763441
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 48, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 72 // All Products= 558 // Extract % = 12.903225806451612
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 72, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 96 // All Products= 558 // Extract % = 17.20430107526882
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 96, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 120 // All Products= 558 // Extract % = 21.50537634408602
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 120, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 144 // All Products= 558 // Extract % = 25.806451612903224
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 144, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 168 // All Products= 558 // Extract % = 30.107526881720432
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 168, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 192 // All Products= 558 // Extract % = 34.40860215053764
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 192, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 216 // All Products= 558 // Extract % = 38.70967741935484
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 216, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 240 // All Products= 558 // Extract % = 43.01075268817204
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 240, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 264 // All Products= 558 // Extract % = 47.31182795698925
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 264, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 288 // All Products= 558 // Extract % = 51.61290322580645
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 288, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 312 // All Products= 558 // Extract % = 55.91397849462365
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 312, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 336 // All Products= 558 // Extract % = 60.215053763440864
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 336, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 360 // All Products= 558 // Extract % = 64.51612903225806
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 360, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 384 // All Products= 558 // Extract % = 68.81720430107528
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 384, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 408 // All Products= 558 // Extract % = 73.11827956989248
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 408, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 432 // All Products= 558 // Extract % = 77.41935483870968
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 432, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 456 // All Products= 558 // Extract % = 81.72043010752688
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 456, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 480 // All Products= 558 // Extract % = 86.02150537634408
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 480, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 504 // All Products= 558 // Extract % = 90.32258064516128
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 504, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 23 // Units = 23 // Products = 24
# Extracted = 528 // All Products= 558 // Extract % = 94.6236559139785
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 528, 'sz': 24}
# Names = 24 // Quantity = 24 // Price-p-Unit = 24 // Units = 24 // Products = 24
# Extracted = 552 // All Products= 558 // Extract % = 98.9247311827957
# https://www.continente.pt/refeicoes-faceis {'pmin': '0.01', 'start': 552, 'sz': 24}
